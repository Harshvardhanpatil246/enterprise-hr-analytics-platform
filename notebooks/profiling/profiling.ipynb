# %% [markdown]
# # DATA PROFILING

# %%
# IMPORT LIABRAIES

import pandas as pd
import numpy as np

# %%
# LOAD DATA

people_data = pd.read_csv(r"C:\Users\HARSHVARDHAN\OneDrive\Desktop\HR_Analytics_Project\data\raw\people_data.csv")

people_employment_history = pd.read_csv(r"C:\Users\HARSHVARDHAN\OneDrive\Desktop\HR_Analytics_Project\data\raw\people_employment_history.csv")

# %%
# CHECK FOR DUPLICATES

people_data.duplicated().sum()
# Out:
# np.int64(0)

# %%
# CHECK DUPLICATE EMPLOYEE_ID IN PEOPLE DATA

people_data['employee_id'].duplicated().sum()
# Out:
# np.int64(0)

# %%
# PROFILE PEOPLE DATA

people_data.head()
# Out:
#    employee_id  gender              race  birth_date          education  \
# 0  12104572130  Female         Caucasian   1/25/1967    Master's degree
# 1      3381966  Female         Caucasian  12/26/1990  Bachelor's degree
# 2     12868764    Male         Caucasian   5/30/1982  Bachelor's degree
# 3     17445638    Male         Caucasian    8/5/1984  Bachelor's degree
# 4     19611331    Male  African American   10/4/1990  Bachelor's degree
#
#   location  location_city marital_status employment_status
# 0  On-site    Los Angeles        Married         Full Time
# 1   Remote  Washington DC         Single         Full Time
# 2  On-site  San Francisco         Single         Full Time
# 3   Remote       Columbus         Single         Full Time
# 4   Remote  Washington DC         Single         Full Time

# %%
# CHECK FOR DUPLICATES IN EMPLOYMENT HISTORY

people_employment_history.duplicated().sum()
# Out:
# np.int64(0)

# %%
# CHECK DUPLICATE EMPLOYEE_ID IN EMPLOYMENT HISTORY

people_employment_history['employee_id'].duplicated().sum()
# Out:
# np.int64(0)

# %%
# PROFILE EMPLOYMENT HISTORY

people_employment_history.head()
# Out:
#    employee_id first_name  last_name department         sub-department  \
# 0  12104572130        Kip    O'Finan  Executive                    NaN
# 1      3381966       Kate     Maceur      Legal  Intellectual Property
# 2     12868764       Bard  Kenneford   Software   Software Development
# 3     17445638        Saw       Sogg  Marketing       Public Relations
# 4     19611331     Cullen     Stiell         HR               Benefits
#
#    first_level_manager  second_level_manager  third_level_manager  \
# 0                  NaN                   NaN                  NaN
# 1         3.278384e+09          1.490362e+09         2.591261e+09
# 2         7.216768e+09          6.279119e+09         6.268712e+09
# 3         6.725256e+09          2.884264e+09         1.949400e+09
# 4         6.064345e+09          8.377150e+09         1.210457e+10
#
#    fourth_level_manager               job_level   salary   hire_date  \
# ...
